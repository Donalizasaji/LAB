# %% [markdown]
# <a href="https://colab.research.google.com/github/Donalizasaji/LAB1ML/blob/main/Lab_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/Groceries_dataset.csv')

# %%
df.head(10)
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk
# 5           4941  14-02-2015        rolls/buns
# 6           4501  08-05-2015  other vegetables
# 7           3803  23-12-2015        pot plants
# 8           2762  20-03-2015        whole milk
# 9           4119  12-02-2015    tropical fruit
